# %% [markdown]
# #         Primeiros passos com o dataset breast-cancer
# ![Machine learning](imagens/mammogram.png)

# %% [markdown]
# # Roteiro
#
# * Coleta dos dados
# * Representação dos dados para um modelo de machine learning
# * Dataset breast-cancer
# * Preparando o dataset

# %% [markdown]
# ## Recaptulando
# ![Machine learning](imagens/DataAnalise.png)

# %% [markdown]
# # Coletar dados
#
# * Que pergunta estou tentando responder?
# * Eu acho que os dados coletados podem responder essa pergunta?
# * Como vou medir o sucesso da minha solução?

# %% [markdown]
# # Representação dos dados para um modelo de machine learning
# ![Machine learning](imagens/dataset.png)

# %% [markdown]
# # Dataset breast-cancer
#
# * https://www.kaggle.com/uciml/breast-cancer-wisconsin-data
#
# *  Que pergunta estou tentando responder?
#
#   R - Consigo prever se um tecido mamário é maligno ou benigno?
#
#
# * Eu acho que os dados coletados podem responder essa pergunta?
#
#  R - Suposição que a partir de uma imagem, a gente consegue extrair características desse núcleo celular que conseguem discriminar entre um núcleo maligno e benigno.
#
#
# * Como vou medir o sucesso da minha solução?
#
#   R - A gente avalia se o algoritmo tá classificando certo as amostras que eu já conheço a saída. Que é a resposta se tumor é maligno ou benigno.

# %% [markdown]
# # Aprendendo com os dados
#
# * Weka
# * Microsoft Azure Machine Learning
# * IBM Watson
# * PYTHON

# %% [markdown]
# # Por que python?
#
# * Facilidade de aprender
# * Bibliotecas do python
# * Comunidade
# * Jupyter notebook

# %% [markdown]
# # Instalando o jupyter notebook
#
# * https://www.python.org/downloads/
# * pip install jupyter notebook
# * pip install (biblioteca que você deseja instalar)
# * numpy, scipy, pandas e scikit-learn

# %% [markdown]
# ## Abrindo o dataset breast-cancer com scikit-learn

# %%
# importando a função load_breast_cancer do módulo datasets do sklearn
from sklearn.datasets import load_breast_cancer

# %%
# salvando o objeto contendo o dataset breast-cancer
cancer = load_breast_cancer()

# %%
# Abrindo nosso dataset utilizando o pandas
import pandas as pd
cancer = pd.read_csv('breast-cancer-wisconsin-data/data.csv', index_col=0)

# %% [markdown]
# ## Terminologia em machine learning
#
# - Cada linha é uma **observação** (também conhecida como: instância, amostra, exemplo)
# - Cada coluna é um **atributo**

# %%
# Visualizando os nomes dos atributos
cancer.target_names
# Out:
# array(['malignant', 'benign'], dtype='<U9')

# %%
# Visualizando o formato do dataset
cancer.shape
# Out:
# (569, 32)

# %%
# Visualizando as 5 primeiras linhas do dataset
cancer.head()
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  texture_worst  \
# id                                            ...
# ...

# %%
# Visualizando as 5 últimas linhas do dataset
cancer.tail()
# Out:
#        diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 926424         M        21.56         22.39          142.00     1479.0
# 926682         M        20.13         28.25          131.20     1261.0
# 926954         M        16.60         28.08          108.30      858.1
# 927241         M        20.60         29.33          140.10     1265.0
# 92751          B         7.76         24.54           47.92      181.0
#
#         smoothness_mean  compactness_mean  concavity_mean  \
# id
# 926424          0.11100           0.11590         0.24390
# 926682          0.09780           0.10340         0.14400
# 926954          0.08455           0.10230         0.09251
# 927241          0.11780           0.27700         0.35140
# 92751           0.05263           0.04362         0.00000
#
#         concave points_mean  symmetry_mean  ...  texture_worst  \
# id                                          ...
# ...

# %% [markdown]
# - Cada valor que nós iremos predizer é chamado de **classe** (também conhecido como: rótulo, saída, resposta)

# %% [markdown]
# # Preparando o dataset
#
# ### 4 requisitos chaves para garantir que os atributos e classes estejam na forma que o scikit-learn espera:
#
# 1. Atributos e classes devem estar em **objetos separados**
# 2. Atributos e classes devem ser **númericos**
# 3. Atributos e classes devem ser **NumPy arrays**
# 4. Atributos e calsses devem possuir **formatos específicos**

# %% [markdown]
# 1. 	Scikit-learn espera ver apenas números nos objetos dos atributos e das classes.

# %%
cancer.diagnosis.tail()
# Out:
# id
# 926424    M
# 926682    M
# 926954    M
# 927241    M
# 92751     B
# Name: diagnosis, dtype: object

# %%
diag = {'M':0, 'B':1}

# %%
cancer.diagnosis = [diag[item] for item in cancer.diagnosis]

# %%
cancer.tail()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 926424          0        21.56         22.39          142.00     1479.0
# 926682          0        20.13         28.25          131.20     1261.0
# 926954          0        16.60         28.08          108.30      858.1
# 927241          0        20.60         29.33          140.10     1265.0
# 92751           1         7.76         24.54           47.92      181.0
#
#         smoothness_mean  compactness_mean  concavity_mean  \
# id
# 926424          0.11100           0.11590         0.24390
# 926682          0.09780           0.10340         0.14400
# 926954          0.08455           0.10230         0.09251
# 927241          0.11780           0.27700         0.35140
# 92751           0.05263           0.04362         0.00000
#
#         concave points_mean  symmetry_mean  ...  texture_worst  \
# id                                          ...
# ...

# %% [markdown]
# 2. Scikit-learn espera que os atributos e as classes sejam passados para o modelo como objetos separados.

# %%
X = cancer.as_matrix(cancer.columns[2:])
# Out:
# c:\users\vinicius\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
y = cancer.as_matrix(['diagnosis'])
# Out:
# c:\users\vinicius\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# 3.	Scikit-learn espera que os atributos e classes sejam armazenados como numpy arrays.

# %%
print(type(X))
print(type(y))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# 4. Os atributos e classes precisam estar em formatos adequados.

# %%
X.shape
# Out:
# (569, 30)

# %%
y.shape
# Out:
# (569, 1)

# %% [markdown]
# ## Comentários ou Dúvidas?
#
# - Email: <suporte@viniciusgalvaoia.com.br>
# - Website: http://viniciusgalvaoia.com.br

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width: 90%;
# /*        margin-left:auto;*/
# /*        margin-right:auto;*/
#     }
#     ul {
#         line-height: 145%;
#         font-size: 90%;
#     }
#     li {
#         margin-bottom: 1em;
#     }
#     h1 {
#         font-family: Helvetica, serif;
#     }
#     h4{
#         margin-top: 12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 130%;
#         width: 90%;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
# /*    .prompt{
#         display: None;
#     }*/
#     .text_cell_render h5 {
# ...
